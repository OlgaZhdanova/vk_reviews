# %%
# создадим функцию, для которой будем строить градиентный спуск
def f(x, y):
    return (1 - x) ** 2 + 100 * (y - x ** 2) ** 2
# создадим градиент (для этого посчитаем частные производные для функции и вернем их в виде кортежа)
def grad(x, y):
    dx = 2 * x - 2 + 100 * (-4 * y * x + 4 * x ** 3)
    dy = 100 * (2 * y - 2 * x ** 2)
    return (dx, dy)

# %%
# x0 - наша изначальная точка; важно, чтобы она сама не являлась минимумом, т.к. градиент в ней застрянет
# мы понимаем, что в данном случае это не минимум, тк подставив эти значение градиент не зануляется
x0 = (0, 0)
# гамма это темп обучения/шаг градиентного спуска (его можно и нужно варьировать) 
# в первом случае поставили гамма = 0.1 и программа сломалась на 6 итерации, т к цифры были слишком большие 
# уменьшили - шамма = 0.01 - теперь кол-во итерация 39, но потом тоже встает
# еще уменьшили и теперь все четко
gamma = 0.001
# текущую точку мы обозначили за нашу первоначальную (потому что так пока что и есть)
x_cur = x0

vals = []
coords = []
i = 0
while True:
    x_new = (x_cur[0] - gamma * grad(*x_cur)[0],
            x_cur[1] - gamma * grad(*x_cur)[1])
    # обозначили ограничение для количества итераций (тоже можно менять) 
    # если значение градиента не равно нулю, не стоит сразу думать, что мы не попали в минимум
    # возможно не хватило кол-ва итераций, и надо просто увеличить его
    if i > 50000:
        break
    x_cur = x_new
    vals.append(f(*x_cur))
    coords.append(x_cur)
    i += 1
    # выводим номер итерации, значение текущей точки, значение функции в этой точке, градиент 
    # если градиент равен нулю, значит мы в минимуме
    print(f"iter={i}; x=({x_cur[0]:.2f}, {x_cur[1]:.2f});"
          f" f(x)={f(*x_cur):.2f}; grad f(x)=({grad(*x_cur)[0]:.2f}, {grad(*x_cur)[1]:.2f})")
# Out:
# iter=1; x=(0.00, 0.00); f(x)=1.00; grad f(x)=(-2.00, -0.00)
# iter=2; x=(0.00, 0.00); f(x)=0.99; grad f(x)=(-1.99, -0.00)
# iter=3; x=(0.01, 0.00); f(x)=0.99; grad f(x)=(-1.99, -0.01)
# iter=4; x=(0.01, 0.00); f(x)=0.98; grad f(x)=(-1.98, -0.01)
# iter=5; x=(0.01, 0.00); f(x)=0.98; grad f(x)=(-1.98, -0.02)
# iter=6; x=(0.01, 0.00); f(x)=0.98; grad f(x)=(-1.98, -0.02)
# iter=7; x=(0.01, 0.00); f(x)=0.97; grad f(x)=(-1.97, -0.03)
# iter=8; x=(0.02, 0.00); f(x)=0.97; grad f(x)=(-1.97, -0.03)
# iter=9; x=(0.02, 0.00); f(x)=0.96; grad f(x)=(-1.96, -0.04)
# iter=10; x=(0.02, 0.00); f(x)=0.96; grad f(x)=(-1.96, -0.05)
# iter=11; x=(0.02, 0.00); f(x)=0.96; grad f(x)=(-1.95, -0.05)
# iter=12; x=(0.02, 0.00); f(x)=0.95; grad f(x)=(-1.95, -0.06)
# iter=13; x=(0.03, 0.00); f(x)=0.95; grad f(x)=(-1.95, -0.07)
# iter=14; x=(0.03, 0.00); f(x)=0.95; grad f(x)=(-1.94, -0.08)
# iter=15; x=(0.03, 0.00); f(x)=0.94; grad f(x)=(-1.94, -0.08)
# iter=16; x=(0.03, 0.00); f(x)=0.94; grad f(x)=(-1.93, -0.09)
# iter=17; x=(0.03, 0.00); f(x)=0.93; grad f(x)=(-1.93, -0.10)
# iter=18; x=(0.04, 0.00); f(x)=0.93; grad f(x)=(-1.92, -0.10)
# iter=19; x=(0.04, 0.00); f(x)=0.93; grad f(x)=(-1.92, -0.11)
# iter=20; x=(0.04, 0.00); f(x)=0.92; grad f(x)=(-1.91, -0.12)
# iter=21; x=(0.04, 0.00); f(x)=0.92; grad f(x)=(-1.91, -0.13)
# iter=22; x=(0.04, 0.00); f(x)=0.92; grad f(x)=(-1.90, -0.13)
# iter=23; x=(0.04, 0.00); f(x)=0.91; grad f(x)=(-1.90, -0.14)
# iter=24; x=(0.05, 0.00); f(x)=0.91; grad f(x)=(-1.89, -0.15)
# iter=25; x=(0.05, 0.00); f(x)=0.91; grad f(x)=(-1.89, -0.15)
# iter=26; x=(0.05, 0.00); f(x)=0.90; grad f(x)=(-1.88, -0.16)
# iter=27; x=(0.05, 0.00); f(x)=0.90; grad f(x)=(-1.88, -0.17)
# iter=28; x=(0.05, 0.00); f(x)=0.89; grad f(x)=(-1.87, -0.17)
# iter=29; x=(0.06, 0.00); f(x)=0.89; grad f(x)=(-1.87, -0.18)
# iter=30; x=(0.06, 0.00); f(x)=0.89; grad f(x)=(-1.86, -0.19)
# iter=31; x=(0.06, 0.00); f(x)=0.88; grad f(x)=(-1.86, -0.19)
# iter=32; x=(0.06, 0.00); f(x)=0.88; grad f(x)=(-1.85, -0.20)
# iter=33; x=(0.06, 0.00); f(x)=0.88; grad f(x)=(-1.85, -0.21)
# iter=34; x=(0.07, 0.00); f(x)=0.87; grad f(x)=(-1.84, -0.21)
# iter=35; x=(0.07, 0.00); f(x)=0.87; grad f(x)=(-1.84, -0.22)
# iter=36; x=(0.07, 0.00); f(x)=0.87; grad f(x)=(-1.83, -0.23)
# iter=37; x=(0.07, 0.00); f(x)=0.86; grad f(x)=(-1.83, -0.23)
# iter=38; x=(0.07, 0.00); f(x)=0.86; grad f(x)=(-1.82, -0.24)
# iter=39; x=(0.07, 0.00); f(x)=0.86; grad f(x)=(-1.81, -0.24)
# iter=40; x=(0.08, 0.00); f(x)=0.85; grad f(x)=(-1.81, -0.25)
# iter=41; x=(0.08, 0.00); f(x)=0.85; grad f(x)=(-1.80, -0.26)
# iter=42; x=(0.08, 0.01); f(x)=0.85; grad f(x)=(-1.80, -0.26)
# iter=43; x=(0.08, 0.01); f(x)=0.84; grad f(x)=(-1.79, -0.27)
# iter=44; x=(0.08, 0.01); f(x)=0.84; grad f(x)=(-1.79, -0.27)
# iter=45; x=(0.09, 0.01); f(x)=0.84; grad f(x)=(-1.78, -0.28)
# iter=46; x=(0.09, 0.01); f(x)=0.83; grad f(x)=(-1.78, -0.28)
# iter=47; x=(0.09, 0.01); f(x)=0.83; grad f(x)=(-1.77, -0.29)
# iter=48; x=(0.09, 0.01); f(x)=0.83; grad f(x)=(-1.76, -0.30)
# iter=49; x=(0.09, 0.01); f(x)=0.82; grad f(x)=(-1.76, -0.30)
# iter=50; x=(0.09, 0.01); f(x)=0.82; grad f(x)=(-1.75, -0.31)
# iter=51; x=(0.10, 0.01); f(x)=0.82; grad f(x)=(-1.75, -0.31)
# iter=52; x=(0.10, 0.01); f(x)=0.81; grad f(x)=(-1.74, -0.32)
# iter=53; x=(0.10, 0.01); f(x)=0.81; grad f(x)=(-1.74, -0.32)
# iter=54; x=(0.10, 0.01); f(x)=0.81; grad f(x)=(-1.73, -0.33)
# iter=55; x=(0.10, 0.01); f(x)=0.80; grad f(x)=(-1.73, -0.33)
# iter=56; x=(0.10, 0.01); f(x)=0.80; grad f(x)=(-1.72, -0.34)
# iter=57; x=(0.11, 0.01); f(x)=0.80; grad f(x)=(-1.71, -0.34)
# iter=58; x=(0.11, 0.01); f(x)=0.80; grad f(x)=(-1.71, -0.35)
# iter=59; x=(0.11, 0.01); f(x)=0.79; grad f(x)=(-1.70, -0.35)
# iter=60; x=(0.11, 0.01); f(x)=0.79; grad f(x)=(-1.70, -0.36)
# iter=61; x=(0.11, 0.01); f(x)=0.79; grad f(x)=(-1.69, -0.36)
# iter=62; x=(0.11, 0.01); f(x)=0.78; grad f(x)=(-1.69, -0.37)
# iter=63; x=(0.12, 0.01); f(x)=0.78; grad f(x)=(-1.68, -0.37)
# iter=64; x=(0.12, 0.01); f(x)=0.78; grad f(x)=(-1.67, -0.38)
# iter=65; x=(0.12, 0.01); f(x)=0.77; grad f(x)=(-1.67, -0.38)
# iter=66; x=(0.12, 0.01); f(x)=0.77; grad f(x)=(-1.66, -0.39)
# iter=67; x=(0.12, 0.01); f(x)=0.77; grad f(x)=(-1.66, -0.39)
# iter=68; x=(0.13, 0.01); f(x)=0.77; grad f(x)=(-1.65, -0.39)
# iter=69; x=(0.13, 0.01); f(x)=0.76; grad f(x)=(-1.65, -0.40)
# iter=70; x=(0.13, 0.01); f(x)=0.76; grad f(x)=(-1.64, -0.40)
# iter=71; x=(0.13, 0.01); f(x)=0.76; grad f(x)=(-1.63, -0.41)
# iter=72; x=(0.13, 0.02); f(x)=0.75; grad f(x)=(-1.63, -0.41)
# iter=73; x=(0.13, 0.02); f(x)=0.75; grad f(x)=(-1.62, -0.42)
# iter=74; x=(0.13, 0.02); f(x)=0.75; grad f(x)=(-1.62, -0.42)
# iter=75; x=(0.14, 0.02); f(x)=0.75; grad f(x)=(-1.61, -0.42)
# iter=76; x=(0.14, 0.02); f(x)=0.74; grad f(x)=(-1.61, -0.43)
# iter=77; x=(0.14, 0.02); f(x)=0.74; grad f(x)=(-1.60, -0.43)
# iter=78; x=(0.14, 0.02); f(x)=0.74; grad f(x)=(-1.59, -0.43)
# iter=79; x=(0.14, 0.02); f(x)=0.74; grad f(x)=(-1.59, -0.44)
# iter=80; x=(0.14, 0.02); f(x)=0.73; grad f(x)=(-1.58, -0.44)
# iter=81; x=(0.15, 0.02); f(x)=0.73; grad f(x)=(-1.58, -0.45)
# iter=82; x=(0.15, 0.02); f(x)=0.73; grad f(x)=(-1.57, -0.45)
# iter=83; x=(0.15, 0.02); f(x)=0.72; grad f(x)=(-1.57, -0.45)
# iter=84; x=(0.15, 0.02); f(x)=0.72; grad f(x)=(-1.56, -0.46)
# iter=85; x=(0.15, 0.02); f(x)=0.72; grad f(x)=(-1.56, -0.46)
# iter=86; x=(0.15, 0.02); f(x)=0.72; grad f(x)=(-1.55, -0.46)
# iter=87; x=(0.16, 0.02); f(x)=0.71; grad f(x)=(-1.54, -0.47)
# iter=88; x=(0.16, 0.02); f(x)=0.71; grad f(x)=(-1.54, -0.47)
# iter=89; x=(0.16, 0.02); f(x)=0.71; grad f(x)=(-1.53, -0.47)
# iter=90; x=(0.16, 0.02); f(x)=0.71; grad f(x)=(-1.53, -0.48)
# iter=91; x=(0.16, 0.02); f(x)=0.70; grad f(x)=(-1.52, -0.48)
# iter=92; x=(0.16, 0.02); f(x)=0.70; grad f(x)=(-1.52, -0.48)
# iter=93; x=(0.16, 0.02); f(x)=0.70; grad f(x)=(-1.51, -0.48)
# iter=94; x=(0.17, 0.03); f(x)=0.70; grad f(x)=(-1.51, -0.49)
# iter=95; x=(0.17, 0.03); f(x)=0.69; grad f(x)=(-1.50, -0.49)
# iter=96; x=(0.17, 0.03); f(x)=0.69; grad f(x)=(-1.49, -0.49)
# iter=97; x=(0.17, 0.03); f(x)=0.69; grad f(x)=(-1.49, -0.50)
# iter=98; x=(0.17, 0.03); f(x)=0.69; grad f(x)=(-1.48, -0.50)
# iter=99; x=(0.17, 0.03); f(x)=0.68; grad f(x)=(-1.48, -0.50)
# iter=100; x=(0.18, 0.03); f(x)=0.68; grad f(x)=(-1.47, -0.50)
# iter=101; x=(0.18, 0.03); f(x)=0.68; grad f(x)=(-1.47, -0.51)
# iter=102; x=(0.18, 0.03); f(x)=0.68; grad f(x)=(-1.46, -0.51)
# iter=103; x=(0.18, 0.03); f(x)=0.67; grad f(x)=(-1.46, -0.51)
# iter=104; x=(0.18, 0.03); f(x)=0.67; grad f(x)=(-1.45, -0.52)
# iter=105; x=(0.18, 0.03); f(x)=0.67; grad f(x)=(-1.45, -0.52)
# iter=106; x=(0.18, 0.03); f(x)=0.67; grad f(x)=(-1.44, -0.52)
# iter=107; x=(0.19, 0.03); f(x)=0.66; grad f(x)=(-1.44, -0.52)
# iter=108; x=(0.19, 0.03); f(x)=0.66; grad f(x)=(-1.43, -0.52)
# iter=109; x=(0.19, 0.03); f(x)=0.66; grad f(x)=(-1.43, -0.53)
# iter=110; x=(0.19, 0.03); f(x)=0.66; grad f(x)=(-1.42, -0.53)
# iter=111; x=(0.19, 0.03); f(x)=0.66; grad f(x)=(-1.42, -0.53)
# iter=112; x=(0.19, 0.03); f(x)=0.65; grad f(x)=(-1.41, -0.53)
# iter=113; x=(0.19, 0.03); f(x)=0.65; grad f(x)=(-1.40, -0.54)
# iter=114; x=(0.20, 0.04); f(x)=0.65; grad f(x)=(-1.40, -0.54)
# iter=115; x=(0.20, 0.04); f(x)=0.65; grad f(x)=(-1.39, -0.54)
# iter=116; x=(0.20, 0.04); f(x)=0.64; grad f(x)=(-1.39, -0.54)
# iter=117; x=(0.20, 0.04); f(x)=0.64; grad f(x)=(-1.38, -0.54)
# iter=118; x=(0.20, 0.04); f(x)=0.64; grad f(x)=(-1.38, -0.55)
# iter=119; x=(0.20, 0.04); f(x)=0.64; grad f(x)=(-1.37, -0.55)
# iter=120; x=(0.20, 0.04); f(x)=0.64; grad f(x)=(-1.37, -0.55)
# iter=121; x=(0.20, 0.04); f(x)=0.63; grad f(x)=(-1.36, -0.55)
# iter=122; x=(0.21, 0.04); f(x)=0.63; grad f(x)=(-1.36, -0.55)
# iter=123; x=(0.21, 0.04); f(x)=0.63; grad f(x)=(-1.35, -0.56)
# iter=124; x=(0.21, 0.04); f(x)=0.63; grad f(x)=(-1.35, -0.56)
# iter=125; x=(0.21, 0.04); f(x)=0.62; grad f(x)=(-1.34, -0.56)
# iter=126; x=(0.21, 0.04); f(x)=0.62; grad f(x)=(-1.34, -0.56)
# iter=127; x=(0.21, 0.04); f(x)=0.62; grad f(x)=(-1.33, -0.56)
# iter=128; x=(0.21, 0.04); f(x)=0.62; grad f(x)=(-1.33, -0.56)
# iter=129; x=(0.22, 0.04); f(x)=0.62; grad f(x)=(-1.32, -0.57)
# iter=130; x=(0.22, 0.04); f(x)=0.61; grad f(x)=(-1.32, -0.57)
# iter=131; x=(0.22, 0.04); f(x)=0.61; grad f(x)=(-1.32, -0.57)
# iter=132; x=(0.22, 0.05); f(x)=0.61; grad f(x)=(-1.31, -0.57)
# iter=133; x=(0.22, 0.05); f(x)=0.61; grad f(x)=(-1.31, -0.57)
# iter=134; x=(0.22, 0.05); f(x)=0.61; grad f(x)=(-1.30, -0.57)
# iter=135; x=(0.22, 0.05); f(x)=0.60; grad f(x)=(-1.30, -0.57)
# iter=136; x=(0.22, 0.05); f(x)=0.60; grad f(x)=(-1.29, -0.58)
# iter=137; x=(0.23, 0.05); f(x)=0.60; grad f(x)=(-1.29, -0.58)
# iter=138; x=(0.23, 0.05); f(x)=0.60; grad f(x)=(-1.28, -0.58)
# iter=139; x=(0.23, 0.05); f(x)=0.60; grad f(x)=(-1.28, -0.58)
# iter=140; x=(0.23, 0.05); f(x)=0.59; grad f(x)=(-1.27, -0.58)
# iter=141; x=(0.23, 0.05); f(x)=0.59; grad f(x)=(-1.27, -0.58)
# iter=142; x=(0.23, 0.05); f(x)=0.59; grad f(x)=(-1.26, -0.58)
# iter=143; x=(0.23, 0.05); f(x)=0.59; grad f(x)=(-1.26, -0.58)
# iter=144; x=(0.24, 0.05); f(x)=0.59; grad f(x)=(-1.25, -0.59)
# iter=145; x=(0.24, 0.05); f(x)=0.58; grad f(x)=(-1.25, -0.59)
# iter=146; x=(0.24, 0.05); f(x)=0.58; grad f(x)=(-1.25, -0.59)
# iter=147; x=(0.24, 0.05); f(x)=0.58; grad f(x)=(-1.24, -0.59)
# iter=148; x=(0.24, 0.05); f(x)=0.58; grad f(x)=(-1.24, -0.59)
# iter=149; x=(0.24, 0.06); f(x)=0.58; grad f(x)=(-1.23, -0.59)
# iter=150; x=(0.24, 0.06); f(x)=0.57; grad f(x)=(-1.23, -0.59)
# iter=151; x=(0.24, 0.06); f(x)=0.57; grad f(x)=(-1.22, -0.59)
# iter=152; x=(0.24, 0.06); f(x)=0.57; grad f(x)=(-1.22, -0.59)
# iter=153; x=(0.25, 0.06); f(x)=0.57; grad f(x)=(-1.21, -0.59)
# iter=154; x=(0.25, 0.06); f(x)=0.57; grad f(x)=(-1.21, -0.60)
# iter=155; x=(0.25, 0.06); f(x)=0.57; grad f(x)=(-1.21, -0.60)
# iter=156; x=(0.25, 0.06); f(x)=0.56; grad f(x)=(-1.20, -0.60)
# iter=157; x=(0.25, 0.06); f(x)=0.56; grad f(x)=(-1.20, -0.60)
# iter=158; x=(0.25, 0.06); f(x)=0.56; grad f(x)=(-1.19, -0.60)
# iter=159; x=(0.25, 0.06); f(x)=0.56; grad f(x)=(-1.19, -0.60)
# iter=160; x=(0.25, 0.06); f(x)=0.56; grad f(x)=(-1.18, -0.60)
# iter=161; x=(0.26, 0.06); f(x)=0.55; grad f(x)=(-1.18, -0.60)
# iter=162; x=(0.26, 0.06); f(x)=0.55; grad f(x)=(-1.18, -0.60)
# iter=163; x=(0.26, 0.06); f(x)=0.55; grad f(x)=(-1.17, -0.60)
# iter=164; x=(0.26, 0.06); f(x)=0.55; grad f(x)=(-1.17, -0.60)
# iter=165; x=(0.26, 0.06); f(x)=0.55; grad f(x)=(-1.16, -0.60)
# iter=166; x=(0.26, 0.07); f(x)=0.55; grad f(x)=(-1.16, -0.61)
# iter=167; x=(0.26, 0.07); f(x)=0.54; grad f(x)=(-1.16, -0.61)
# iter=168; x=(0.26, 0.07); f(x)=0.54; grad f(x)=(-1.15, -0.61)
# iter=169; x=(0.27, 0.07); f(x)=0.54; grad f(x)=(-1.15, -0.61)
# iter=170; x=(0.27, 0.07); f(x)=0.54; grad f(x)=(-1.14, -0.61)
# iter=171; x=(0.27, 0.07); f(x)=0.54; grad f(x)=(-1.14, -0.61)
# iter=172; x=(0.27, 0.07); f(x)=0.54; grad f(x)=(-1.14, -0.61)
# iter=173; x=(0.27, 0.07); f(x)=0.53; grad f(x)=(-1.13, -0.61)
# iter=174; x=(0.27, 0.07); f(x)=0.53; grad f(x)=(-1.13, -0.61)
# iter=175; x=(0.27, 0.07); f(x)=0.53; grad f(x)=(-1.12, -0.61)
# iter=176; x=(0.27, 0.07); f(x)=0.53; grad f(x)=(-1.12, -0.61)
# iter=177; x=(0.27, 0.07); f(x)=0.53; grad f(x)=(-1.12, -0.61)
# iter=178; x=(0.28, 0.07); f(x)=0.53; grad f(x)=(-1.11, -0.61)
# iter=179; x=(0.28, 0.07); f(x)=0.52; grad f(x)=(-1.11, -0.61)
# iter=180; x=(0.28, 0.07); f(x)=0.52; grad f(x)=(-1.10, -0.61)
# iter=181; x=(0.28, 0.07); f(x)=0.52; grad f(x)=(-1.10, -0.61)
# iter=182; x=(0.28, 0.08); f(x)=0.52; grad f(x)=(-1.10, -0.61)
# iter=183; x=(0.28, 0.08); f(x)=0.52; grad f(x)=(-1.09, -0.61)
# iter=184; x=(0.28, 0.08); f(x)=0.52; grad f(x)=(-1.09, -0.61)
# iter=185; x=(0.28, 0.08); f(x)=0.52; grad f(x)=(-1.09, -0.61)
# iter=186; x=(0.28, 0.08); f(x)=0.51; grad f(x)=(-1.08, -0.61)
# iter=187; x=(0.29, 0.08); f(x)=0.51; grad f(x)=(-1.08, -0.62)
# iter=188; x=(0.29, 0.08); f(x)=0.51; grad f(x)=(-1.08, -0.62)
# iter=189; x=(0.29, 0.08); f(x)=0.51; grad f(x)=(-1.07, -0.62)
# iter=190; x=(0.29, 0.08); f(x)=0.51; grad f(x)=(-1.07, -0.62)
# iter=191; x=(0.29, 0.08); f(x)=0.51; grad f(x)=(-1.06, -0.62)
# iter=192; x=(0.29, 0.08); f(x)=0.50; grad f(x)=(-1.06, -0.62)
# iter=193; x=(0.29, 0.08); f(x)=0.50; grad f(x)=(-1.06, -0.62)
# iter=194; x=(0.29, 0.08); f(x)=0.50; grad f(x)=(-1.05, -0.62)
# iter=195; x=(0.29, 0.08); f(x)=0.50; grad f(x)=(-1.05, -0.62)
# iter=196; x=(0.29, 0.08); f(x)=0.50; grad f(x)=(-1.05, -0.62)
# iter=197; x=(0.30, 0.08); f(x)=0.50; grad f(x)=(-1.04, -0.62)
# iter=198; x=(0.30, 0.09); f(x)=0.50; grad f(x)=(-1.04, -0.62)
# iter=199; x=(0.30, 0.09); f(x)=0.49; grad f(x)=(-1.04, -0.62)
# iter=200; x=(0.30, 0.09); f(x)=0.49; grad f(x)=(-1.03, -0.62)
# iter=201; x=(0.30, 0.09); f(x)=0.49; grad f(x)=(-1.03, -0.62)
# iter=202; x=(0.30, 0.09); f(x)=0.49; grad f(x)=(-1.03, -0.62)
# iter=203; x=(0.30, 0.09); f(x)=0.49; grad f(x)=(-1.02, -0.62)
# iter=204; x=(0.30, 0.09); f(x)=0.49; grad f(x)=(-1.02, -0.62)
# iter=205; x=(0.30, 0.09); f(x)=0.49; grad f(x)=(-1.02, -0.62)
# iter=206; x=(0.31, 0.09); f(x)=0.48; grad f(x)=(-1.01, -0.62)
# iter=207; x=(0.31, 0.09); f(x)=0.48; grad f(x)=(-1.01, -0.62)
# iter=208; x=(0.31, 0.09); f(x)=0.48; grad f(x)=(-1.01, -0.62)
# iter=209; x=(0.31, 0.09); f(x)=0.48; grad f(x)=(-1.00, -0.62)
# iter=210; x=(0.31, 0.09); f(x)=0.48; grad f(x)=(-1.00, -0.62)
# iter=211; x=(0.31, 0.09); f(x)=0.48; grad f(x)=(-1.00, -0.62)
# iter=212; x=(0.31, 0.09); f(x)=0.48; grad f(x)=(-0.99, -0.62)
# iter=213; x=(0.31, 0.09); f(x)=0.47; grad f(x)=(-0.99, -0.62)
# iter=214; x=(0.31, 0.09); f(x)=0.47; grad f(x)=(-0.99, -0.62)
# iter=215; x=(0.31, 0.10); f(x)=0.47; grad f(x)=(-0.98, -0.62)
# iter=216; x=(0.32, 0.10); f(x)=0.47; grad f(x)=(-0.98, -0.62)
# iter=217; x=(0.32, 0.10); f(x)=0.47; grad f(x)=(-0.98, -0.62)
# iter=218; x=(0.32, 0.10); f(x)=0.47; grad f(x)=(-0.97, -0.62)
# iter=219; x=(0.32, 0.10); f(x)=0.47; grad f(x)=(-0.97, -0.62)
# iter=220; x=(0.32, 0.10); f(x)=0.46; grad f(x)=(-0.97, -0.62)
# iter=221; x=(0.32, 0.10); f(x)=0.46; grad f(x)=(-0.96, -0.62)
# iter=222; x=(0.32, 0.10); f(x)=0.46; grad f(x)=(-0.96, -0.62)
# iter=223; x=(0.32, 0.10); f(x)=0.46; grad f(x)=(-0.96, -0.62)
# iter=224; x=(0.32, 0.10); f(x)=0.46; grad f(x)=(-0.96, -0.62)
# iter=225; x=(0.32, 0.10); f(x)=0.46; grad f(x)=(-0.95, -0.62)
# iter=226; x=(0.32, 0.10); f(x)=0.46; grad f(x)=(-0.95, -0.62)
# iter=227; x=(0.33, 0.10); f(x)=0.46; grad f(x)=(-0.95, -0.62)
# iter=228; x=(0.33, 0.10); f(x)=0.45; grad f(x)=(-0.94, -0.62)
# iter=229; x=(0.33, 0.10); f(x)=0.45; grad f(x)=(-0.94, -0.62)
# iter=230; x=(0.33, 0.10); f(x)=0.45; grad f(x)=(-0.94, -0.62)
# iter=231; x=(0.33, 0.11); f(x)=0.45; grad f(x)=(-0.93, -0.62)
# iter=232; x=(0.33, 0.11); f(x)=0.45; grad f(x)=(-0.93, -0.62)
# iter=233; x=(0.33, 0.11); f(x)=0.45; grad f(x)=(-0.93, -0.62)
# iter=234; x=(0.33, 0.11); f(x)=0.45; grad f(x)=(-0.93, -0.62)
# iter=235; x=(0.33, 0.11); f(x)=0.45; grad f(x)=(-0.92, -0.62)
# iter=236; x=(0.33, 0.11); f(x)=0.44; grad f(x)=(-0.92, -0.62)
# iter=237; x=(0.33, 0.11); f(x)=0.44; grad f(x)=(-0.92, -0.62)
# iter=238; x=(0.34, 0.11); f(x)=0.44; grad f(x)=(-0.91, -0.62)
# iter=239; x=(0.34, 0.11); f(x)=0.44; grad f(x)=(-0.91, -0.62)
# iter=240; x=(0.34, 0.11); f(x)=0.44; grad f(x)=(-0.91, -0.62)
# iter=241; x=(0.34, 0.11); f(x)=0.44; grad f(x)=(-0.91, -0.62)
# iter=242; x=(0.34, 0.11); f(x)=0.44; grad f(x)=(-0.90, -0.62)
# iter=243; x=(0.34, 0.11); f(x)=0.44; grad f(x)=(-0.90, -0.62)
# iter=244; x=(0.34, 0.11); f(x)=0.43; grad f(x)=(-0.90, -0.61)
# iter=245; x=(0.34, 0.11); f(x)=0.43; grad f(x)=(-0.89, -0.61)
# iter=246; x=(0.34, 0.11); f(x)=0.43; grad f(x)=(-0.89, -0.61)
# iter=247; x=(0.34, 0.12); f(x)=0.43; grad f(x)=(-0.89, -0.61)
# iter=248; x=(0.34, 0.12); f(x)=0.43; grad f(x)=(-0.89, -0.61)
# iter=249; x=(0.35, 0.12); f(x)=0.43; grad f(x)=(-0.88, -0.61)
# iter=250; x=(0.35, 0.12); f(x)=0.43; grad f(x)=(-0.88, -0.61)
# iter=251; x=(0.35, 0.12); f(x)=0.43; grad f(x)=(-0.88, -0.61)
# iter=252; x=(0.35, 0.12); f(x)=0.43; grad f(x)=(-0.88, -0.61)
# iter=253; x=(0.35, 0.12); f(x)=0.42; grad f(x)=(-0.87, -0.61)
# iter=254; x=(0.35, 0.12); f(x)=0.42; grad f(x)=(-0.87, -0.61)
# iter=255; x=(0.35, 0.12); f(x)=0.42; grad f(x)=(-0.87, -0.61)
# iter=256; x=(0.35, 0.12); f(x)=0.42; grad f(x)=(-0.87, -0.61)
# iter=257; x=(0.35, 0.12); f(x)=0.42; grad f(x)=(-0.86, -0.61)
# iter=258; x=(0.35, 0.12); f(x)=0.42; grad f(x)=(-0.86, -0.61)
# iter=259; x=(0.35, 0.12); f(x)=0.42; grad f(x)=(-0.86, -0.61)
# iter=260; x=(0.36, 0.12); f(x)=0.42; grad f(x)=(-0.86, -0.61)
# iter=261; x=(0.36, 0.12); f(x)=0.42; grad f(x)=(-0.85, -0.61)
# iter=262; x=(0.36, 0.12); f(x)=0.41; grad f(x)=(-0.85, -0.61)
# iter=263; x=(0.36, 0.13); f(x)=0.41; grad f(x)=(-0.85, -0.61)
# iter=264; x=(0.36, 0.13); f(x)=0.41; grad f(x)=(-0.85, -0.61)
# iter=265; x=(0.36, 0.13); f(x)=0.41; grad f(x)=(-0.84, -0.61)
# iter=266; x=(0.36, 0.13); f(x)=0.41; grad f(x)=(-0.84, -0.61)
# iter=267; x=(0.36, 0.13); f(x)=0.41; grad f(x)=(-0.84, -0.61)
# iter=268; x=(0.36, 0.13); f(x)=0.41; grad f(x)=(-0.84, -0.61)
# iter=269; x=(0.36, 0.13); f(x)=0.41; grad f(x)=(-0.83, -0.61)
# iter=270; x=(0.36, 0.13); f(x)=0.41; grad f(x)=(-0.83, -0.61)
# iter=271; x=(0.36, 0.13); f(x)=0.40; grad f(x)=(-0.83, -0.61)
# iter=272; x=(0.37, 0.13); f(x)=0.40; grad f(x)=(-0.83, -0.61)
# iter=273; x=(0.37, 0.13); f(x)=0.40; grad f(x)=(-0.82, -0.61)
# iter=274; x=(0.37, 0.13); f(x)=0.40; grad f(x)=(-0.82, -0.61)
# iter=275; x=(0.37, 0.13); f(x)=0.40; grad f(x)=(-0.82, -0.61)
# iter=276; x=(0.37, 0.13); f(x)=0.40; grad f(x)=(-0.82, -0.60)
# iter=277; x=(0.37, 0.13); f(x)=0.40; grad f(x)=(-0.81, -0.60)
# iter=278; x=(0.37, 0.13); f(x)=0.40; grad f(x)=(-0.81, -0.60)
# iter=279; x=(0.37, 0.13); f(x)=0.40; grad f(x)=(-0.81, -0.60)
# iter=280; x=(0.37, 0.14); f(x)=0.40; grad f(x)=(-0.81, -0.60)
# iter=281; x=(0.37, 0.14); f(x)=0.39; grad f(x)=(-0.80, -0.60)
# iter=282; x=(0.37, 0.14); f(x)=0.39; grad f(x)=(-0.80, -0.60)
# iter=283; x=(0.37, 0.14); f(x)=0.39; grad f(x)=(-0.80, -0.60)
# iter=284; x=(0.38, 0.14); f(x)=0.39; grad f(x)=(-0.80, -0.60)
# iter=285; x=(0.38, 0.14); f(x)=0.39; grad f(x)=(-0.80, -0.60)
# iter=286; x=(0.38, 0.14); f(x)=0.39; grad f(x)=(-0.79, -0.60)
# iter=287; x=(0.38, 0.14); f(x)=0.39; grad f(x)=(-0.79, -0.60)
# iter=288; x=(0.38, 0.14); f(x)=0.39; grad f(x)=(-0.79, -0.60)
# iter=289; x=(0.38, 0.14); f(x)=0.39; grad f(x)=(-0.79, -0.60)
# iter=290; x=(0.38, 0.14); f(x)=0.39; grad f(x)=(-0.78, -0.60)
# iter=291; x=(0.38, 0.14); f(x)=0.38; grad f(x)=(-0.78, -0.60)
# iter=292; x=(0.38, 0.14); f(x)=0.38; grad f(x)=(-0.78, -0.60)
# iter=293; x=(0.38, 0.14); f(x)=0.38; grad f(x)=(-0.78, -0.60)
# iter=294; x=(0.38, 0.14); f(x)=0.38; grad f(x)=(-0.78, -0.60)
# iter=295; x=(0.38, 0.14); f(x)=0.38; grad f(x)=(-0.77, -0.60)
# iter=296; x=(0.38, 0.14); f(x)=0.38; grad f(x)=(-0.77, -0.60)
# iter=297; x=(0.39, 0.15); f(x)=0.38; grad f(x)=(-0.77, -0.60)
# iter=298; x=(0.39, 0.15); f(x)=0.38; grad f(x)=(-0.77, -0.60)
# iter=299; x=(0.39, 0.15); f(x)=0.38; grad f(x)=(-0.77, -0.60)
# iter=300; x=(0.39, 0.15); f(x)=0.38; grad f(x)=(-0.76, -0.59)
# iter=301; x=(0.39, 0.15); f(x)=0.37; grad f(x)=(-0.76, -0.59)
# iter=302; x=(0.39, 0.15); f(x)=0.37; grad f(x)=(-0.76, -0.59)
# iter=303; x=(0.39, 0.15); f(x)=0.37; grad f(x)=(-0.76, -0.59)
# iter=304; x=(0.39, 0.15); f(x)=0.37; grad f(x)=(-0.75, -0.59)
# iter=305; x=(0.39, 0.15); f(x)=0.37; grad f(x)=(-0.75, -0.59)
# iter=306; x=(0.39, 0.15); f(x)=0.37; grad f(x)=(-0.75, -0.59)
# iter=307; x=(0.39, 0.15); f(x)=0.37; grad f(x)=(-0.75, -0.59)
# iter=308; x=(0.39, 0.15); f(x)=0.37; grad f(x)=(-0.75, -0.59)
# iter=309; x=(0.39, 0.15); f(x)=0.37; grad f(x)=(-0.74, -0.59)
# iter=310; x=(0.40, 0.15); f(x)=0.37; grad f(x)=(-0.74, -0.59)
# iter=311; x=(0.40, 0.15); f(x)=0.37; grad f(x)=(-0.74, -0.59)
# iter=312; x=(0.40, 0.15); f(x)=0.36; grad f(x)=(-0.74, -0.59)
# iter=313; x=(0.40, 0.16); f(x)=0.36; grad f(x)=(-0.74, -0.59)
# iter=314; x=(0.40, 0.16); f(x)=0.36; grad f(x)=(-0.73, -0.59)
# iter=315; x=(0.40, 0.16); f(x)=0.36; grad f(x)=(-0.73, -0.59)
# iter=316; x=(0.40, 0.16); f(x)=0.36; grad f(x)=(-0.73, -0.59)
# iter=317; x=(0.40, 0.16); f(x)=0.36; grad f(x)=(-0.73, -0.59)
# iter=318; x=(0.40, 0.16); f(x)=0.36; grad f(x)=(-0.73, -0.59)
# iter=319; x=(0.40, 0.16); f(x)=0.36; grad f(x)=(-0.73, -0.59)
# iter=320; x=(0.40, 0.16); f(x)=0.36; grad f(x)=(-0.72, -0.59)
# iter=321; x=(0.40, 0.16); f(x)=0.36; grad f(x)=(-0.72, -0.58)
# iter=322; x=(0.40, 0.16); f(x)=0.36; grad f(x)=(-0.72, -0.58)
# iter=323; x=(0.40, 0.16); f(x)=0.36; grad f(x)=(-0.72, -0.58)
# iter=324; x=(0.41, 0.16); f(x)=0.35; grad f(x)=(-0.72, -0.58)
# iter=325; x=(0.41, 0.16); f(x)=0.35; grad f(x)=(-0.71, -0.58)
# iter=326; x=(0.41, 0.16); f(x)=0.35; grad f(x)=(-0.71, -0.58)
# iter=327; x=(0.41, 0.16); f(x)=0.35; grad f(x)=(-0.71, -0.58)
# iter=328; x=(0.41, 0.16); f(x)=0.35; grad f(x)=(-0.71, -0.58)
# iter=329; x=(0.41, 0.16); f(x)=0.35; grad f(x)=(-0.71, -0.58)
# iter=330; x=(0.41, 0.17); f(x)=0.35; grad f(x)=(-0.70, -0.58)
# iter=331; x=(0.41, 0.17); f(x)=0.35; grad f(x)=(-0.70, -0.58)
# iter=332; x=(0.41, 0.17); f(x)=0.35; grad f(x)=(-0.70, -0.58)
# iter=333; x=(0.41, 0.17); f(x)=0.35; grad f(x)=(-0.70, -0.58)
# iter=334; x=(0.41, 0.17); f(x)=0.35; grad f(x)=(-0.70, -0.58)
# iter=335; x=(0.41, 0.17); f(x)=0.35; grad f(x)=(-0.70, -0.58)
# iter=336; x=(0.41, 0.17); f(x)=0.34; grad f(x)=(-0.69, -0.58)
# iter=337; x=(0.41, 0.17); f(x)=0.34; grad f(x)=(-0.69, -0.58)
# iter=338; x=(0.42, 0.17); f(x)=0.34; grad f(x)=(-0.69, -0.58)
# iter=339; x=(0.42, 0.17); f(x)=0.34; grad f(x)=(-0.69, -0.58)
# iter=340; x=(0.42, 0.17); f(x)=0.34; grad f(x)=(-0.69, -0.58)
# iter=341; x=(0.42, 0.17); f(x)=0.34; grad f(x)=(-0.69, -0.57)
# iter=342; x=(0.42, 0.17); f(x)=0.34; grad f(x)=(-0.68, -0.57)
# iter=343; x=(0.42, 0.17); f(x)=0.34; grad f(x)=(-0.68, -0.57)
# iter=344; x=(0.42, 0.17); f(x)=0.34; grad f(x)=(-0.68, -0.57)
# iter=345; x=(0.42, 0.17); f(x)=0.34; grad f(x)=(-0.68, -0.57)
# iter=346; x=(0.42, 0.17); f(x)=0.34; grad f(x)=(-0.68, -0.57)
# iter=347; x=(0.42, 0.17); f(x)=0.34; grad f(x)=(-0.67, -0.57)
# iter=348; x=(0.42, 0.18); f(x)=0.33; grad f(x)=(-0.67, -0.57)
# iter=349; x=(0.42, 0.18); f(x)=0.33; grad f(x)=(-0.67, -0.57)
# iter=350; x=(0.42, 0.18); f(x)=0.33; grad f(x)=(-0.67, -0.57)
# iter=351; x=(0.42, 0.18); f(x)=0.33; grad f(x)=(-0.67, -0.57)
# iter=352; x=(0.42, 0.18); f(x)=0.33; grad f(x)=(-0.67, -0.57)
# iter=353; x=(0.43, 0.18); f(x)=0.33; grad f(x)=(-0.66, -0.57)
# iter=354; x=(0.43, 0.18); f(x)=0.33; grad f(x)=(-0.66, -0.57)
# iter=355; x=(0.43, 0.18); f(x)=0.33; grad f(x)=(-0.66, -0.57)
# iter=356; x=(0.43, 0.18); f(x)=0.33; grad f(x)=(-0.66, -0.57)
# iter=357; x=(0.43, 0.18); f(x)=0.33; grad f(x)=(-0.66, -0.57)
# iter=358; x=(0.43, 0.18); f(x)=0.33; grad f(x)=(-0.66, -0.57)
# iter=359; x=(0.43, 0.18); f(x)=0.33; grad f(x)=(-0.66, -0.57)
# iter=360; x=(0.43, 0.18); f(x)=0.33; grad f(x)=(-0.65, -0.57)
# iter=361; x=(0.43, 0.18); f(x)=0.32; grad f(x)=(-0.65, -0.56)
# iter=362; x=(0.43, 0.18); f(x)=0.32; grad f(x)=(-0.65, -0.56)
# iter=363; x=(0.43, 0.18); f(x)=0.32; grad f(x)=(-0.65, -0.56)
# iter=364; x=(0.43, 0.18); f(x)=0.32; grad f(x)=(-0.65, -0.56)
# iter=365; x=(0.43, 0.19); f(x)=0.32; grad f(x)=(-0.65, -0.56)
# iter=366; x=(0.43, 0.19); f(x)=0.32; grad f(x)=(-0.64, -0.56)
# iter=367; x=(0.43, 0.19); f(x)=0.32; grad f(x)=(-0.64, -0.56)
# iter=368; x=(0.44, 0.19); f(x)=0.32; grad f(x)=(-0.64, -0.56)
# iter=369; x=(0.44, 0.19); f(x)=0.32; grad f(x)=(-0.64, -0.56)
# iter=370; x=(0.44, 0.19); f(x)=0.32; grad f(x)=(-0.64, -0.56)
# iter=371; x=(0.44, 0.19); f(x)=0.32; grad f(x)=(-0.64, -0.56)
# iter=372; x=(0.44, 0.19); f(x)=0.32; grad f(x)=(-0.63, -0.56)
# iter=373; x=(0.44, 0.19); f(x)=0.32; grad f(x)=(-0.63, -0.56)
# iter=374; x=(0.44, 0.19); f(x)=0.32; grad f(x)=(-0.63, -0.56)
# iter=375; x=(0.44, 0.19); f(x)=0.31; grad f(x)=(-0.63, -0.56)
# iter=376; x=(0.44, 0.19); f(x)=0.31; grad f(x)=(-0.63, -0.56)
# iter=377; x=(0.44, 0.19); f(x)=0.31; grad f(x)=(-0.63, -0.56)
# iter=378; x=(0.44, 0.19); f(x)=0.31; grad f(x)=(-0.63, -0.56)
# iter=379; x=(0.44, 0.19); f(x)=0.31; grad f(x)=(-0.62, -0.56)
# iter=380; x=(0.44, 0.19); f(x)=0.31; grad f(x)=(-0.62, -0.55)
# iter=381; x=(0.44, 0.19); f(x)=0.31; grad f(x)=(-0.62, -0.55)
# iter=382; x=(0.44, 0.19); f(x)=0.31; grad f(x)=(-0.62, -0.55)
# iter=383; x=(0.44, 0.20); f(x)=0.31; grad f(x)=(-0.62, -0.55)
# iter=384; x=(0.45, 0.20); f(x)=0.31; grad f(x)=(-0.62, -0.55)
# iter=385; x=(0.45, 0.20); f(x)=0.31; grad f(x)=(-0.62, -0.55)
# iter=386; x=(0.45, 0.20); f(x)=0.31; grad f(x)=(-0.61, -0.55)
# iter=387; x=(0.45, 0.20); f(x)=0.31; grad f(x)=(-0.61, -0.55)
# iter=388; x=(0.45, 0.20); f(x)=0.31; grad f(x)=(-0.61, -0.55)
# iter=389; x=(0.45, 0.20); f(x)=0.30; grad f(x)=(-0.61, -0.55)
# iter=390; x=(0.45, 0.20); f(x)=0.30; grad f(x)=(-0.61, -0.55)
# iter=391; x=(0.45, 0.20); f(x)=0.30; grad f(x)=(-0.61, -0.55)
# iter=392; x=(0.45, 0.20); f(x)=0.30; grad f(x)=(-0.61, -0.55)
# iter=393; x=(0.45, 0.20); f(x)=0.30; grad f(x)=(-0.60, -0.55)
# iter=394; x=(0.45, 0.20); f(x)=0.30; grad f(x)=(-0.60, -0.55)
# iter=395; x=(0.45, 0.20); f(x)=0.30; grad f(x)=(-0.60, -0.55)
# iter=396; x=(0.45, 0.20); f(x)=0.30; grad f(x)=(-0.60, -0.55)
# iter=397; x=(0.45, 0.20); f(x)=0.30; grad f(x)=(-0.60, -0.55)
# iter=398; x=(0.45, 0.20); f(x)=0.30; grad f(x)=(-0.60, -0.55)
# iter=399; x=(0.45, 0.20); f(x)=0.30; grad f(x)=(-0.60, -0.54)
# iter=400; x=(0.46, 0.20); f(x)=0.30; grad f(x)=(-0.59, -0.54)
# iter=401; x=(0.46, 0.20); f(x)=0.30; grad f(x)=(-0.59, -0.54)
# iter=402; x=(0.46, 0.21); f(x)=0.30; grad f(x)=(-0.59, -0.54)
# iter=403; x=(0.46, 0.21); f(x)=0.30; grad f(x)=(-0.59, -0.54)
# iter=404; x=(0.46, 0.21); f(x)=0.30; grad f(x)=(-0.59, -0.54)
# iter=405; x=(0.46, 0.21); f(x)=0.29; grad f(x)=(-0.59, -0.54)
# iter=406; x=(0.46, 0.21); f(x)=0.29; grad f(x)=(-0.59, -0.54)
# iter